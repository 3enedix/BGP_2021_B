# %% [markdown]
# ## Exploratory Data Analysis Part II: Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
data = pd.read_sql_table('merged_weekly', 'postgresql://s2495929:_s2495929_@gip.itc.utwente.nl:5434/c211')

# %%
data.head()
# Out:
#    block  woy  observer_intensity  precipitation  temperature  pop001  pop009  \
# 0     62    5                   1       0.639962     3.590568    30.0  1810.0
# 1     62    7                   2       1.980910     9.501856    30.0  1810.0
# 2     62   15                   1       0.576049    11.472997    30.0  1810.0
# 3     66    1                   1       1.402129     5.060628   140.0   165.0
# 4     66    2                   1       3.684646     4.884237   140.0   165.0
#
#    pop025  pop049  pop081  ...  company_site  wet_natural_terrain  airport  \
# 0  2070.0  2665.0  4025.0  ...  51165.563101             0.000000      0.0
# 1  2070.0  2665.0  4025.0  ...  51165.563101             0.000000      0.0
# 2  2070.0  2665.0  4025.0  ...  51165.563101             0.000000      0.0
# 3   640.0   880.0  1240.0  ...      0.000000         20457.761821      0.0
# 4   640.0   880.0  1240.0  ...      0.000000         20457.761821      0.0
#
# ...

# %% [markdown]
# ### Random statistics

# %%
data.describe()
# Out:
#                block            woy  observer_intensity  precipitation  \
# count  284329.000000  284329.000000       284329.000000  283177.000000
# mean    21422.037710      12.525768            2.375906       1.762092
# std     12890.414861       6.976670            4.079049       1.762594
# min        60.000000       1.000000            1.000000       0.000000
# 25%      9982.000000       7.000000            1.000000       0.411395
# 50%     20340.000000      13.000000            1.000000       1.290850
# 75%     32218.000000      18.000000            2.000000       2.543711
# max     44844.000000      25.000000          383.000000      17.255071
#
#          temperature         pop001         pop009         pop025  \
# count  283637.000000  283183.000000  283183.000000  283183.000000
# mean       13.418459     725.610895    6424.861627   17371.397718
# std         6.660655    1718.466979   11979.261335   28086.846047
# ...

# %% [markdown]
# ### Landuse: Percentage of of total area of the Netherlands per landcover type

# %%
perc_land_cover = pd.DataFrame()
for lcover in ['built_up', 'dry_natural_terrain', 'greenhouse_horticulture', 'railway', 'nature_reserves', 'company_site', 'wet_natural_terrain', 'airport',
               'forest', 'coastal_water', 'semi_built', 'agriculture', 'recreation', 'water', 'highway']:
    perc_land_cover.at[0,lcover] = round(data[lcover].sum()/(len(data)*1000*1000),2)
perc_land_cover
# Out:
#    built_up  dry_natural_terrain  greenhouse_horticulture  railway  \
# 0      0.11                 0.04                      0.0      0.0
#
#    nature_reserves  company_site  wet_natural_terrain  airport  forest  \
# 0             0.18          0.03                 0.03      0.0     0.1
#
#    coastal_water  semi_built  agriculture  recreation  water  highway
# 0           0.03        0.02         0.49        0.04   0.08     0.03

# %%
perc_land_cover.sum().sum()
# ARG §&/%=")§/%()=$"(%/)§
# Out:
# 1.1800000000000002

# %%
perc_land_cover.plot.bar(figsize=(11,5), grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Normalise Data

# %%
data_norm = pd.DataFrame()
for (colname, coldata) in data.iteritems(): # go through columns of dataframe
    if colname == 'obsdate' \
    or colname == 'block' \
    or colname == 'observer_intensity' \
    or colname == 'mdate' \
    or colname == 'holiday' \
    or colname == 'work_day':
        data_norm[colname] = data[colname]
    else:
        data_norm[colname] = (data[colname] - data[colname].mean()) / (data[colname].max() - data[colname].min())

# %%
data_norm.head()
# Out:
#    block       woy  observer_intensity  precipitation  temperature    pop001  \
# 0     62 -0.313574                   1      -0.065032    -0.346928 -0.030469
# 1     62 -0.230240                   2       0.012681    -0.138257 -0.030469
# 2     62  0.103093                   1      -0.068736    -0.068675 -0.030469
# 3     66 -0.480240                   1      -0.020861    -0.295034 -0.025651
# 4     66 -0.438574                   1       0.111420    -0.301261 -0.025651
#
#      pop009    pop025    pop049    pop081  ...  company_site  \
# 0 -0.031711 -0.046196 -0.063268 -0.080992  ...      0.023369
# 1 -0.031711 -0.046196 -0.063268 -0.080992  ...      0.023369
# 2 -0.031711 -0.046196 -0.063268 -0.080992  ...      0.023369
# 3 -0.043014 -0.050514 -0.066993 -0.085610  ...     -0.028860
# 4 -0.043014 -0.050514 -0.066993 -0.085610  ...     -0.028860
#
#    wet_natural_terrain   airport    forest  coastal_water  semi_built  \
# ...

# %%
data_norm.describe()
# Out:
#                block           woy  observer_intensity  precipitation  \
# count  284329.000000  2.843290e+05       284329.000000   2.831770e+05
# mean    21422.037710 -9.666350e-16            2.375906   3.464344e-15
# std     12890.414861  2.906946e-01            4.079049   1.021493e-01
# min        60.000000 -4.802403e-01            1.000000  -1.021202e-01
# 25%      9982.000000 -2.302403e-01            1.000000  -7.827824e-02
# 50%     20340.000000  1.975968e-02            1.000000  -2.731037e-02
# 75%     32218.000000  2.280930e-01            2.000000   4.529793e-02
# max     44844.000000  5.197597e-01          383.000000   8.978798e-01
#
#         temperature        pop001        pop009        pop025        pop049  \
# count  2.836370e+05  2.831830e+05  2.831830e+05  2.831830e+05  2.831830e+05
# mean  -6.750539e-15  6.109340e-16 -2.645238e-16 -7.957468e-17 -4.531899e-16
# std    2.351232e-01  7.527232e-02  8.231472e-02  8.479688e-02  9.986521e-02
# ...

# %% [raw]
# print('min: ', min(data['observer_intensity']))
# print('max: ', max(data['observer_intensity']))
# print('mean: ', data['observer_intensity'].mean())
# print('median: ', data['observer_intensity'].median())
# print('mode: ', data['observer_intensity'].mode())
# print('standard deviation: ', data['observer_intensity'].std())

# %% [raw]
# data_norm['observer_intensity'].quantile([0,0.25,0.5,0.75,1])

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hist(data_norm['observer_intensity'][data_norm['observer_intensity'] <= 10], bins=10)
plt.title('Observer Intensity')
# Out:
# Text(0.5, 1.0, 'Observer Intensity')

# %%
fig, ax = plt.subplots(figsize=(10,5))
data_norm['observer_intensity'][data_norm['observer_intensity'] <= 10].plot(kind='kde')
plt.title('Observer Intensity: Probability Density Function')
# Out:
# Text(0.5, 1.0, 'Observer Intensity: Probability Density Function')

# %% [markdown]
# ### Histograms for some of the parameters

# %%
data_norm.hist(column=['precipitation', 'temperature', 'pop001', 'roadlength'],bins=10, figsize=(14, 10))
# Out:
# array([[<AxesSubplot:title={'center':'precipitation'}>,
#         <AxesSubplot:title={'center':'temperature'}>],
#        [<AxesSubplot:title={'center':'pop001'}>,
#         <AxesSubplot:title={'center':'roadlength'}>]], dtype=object)

# %% [markdown]
# ### Correlations

# %%
corr = data_norm.corr()
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data_norm.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data_norm.columns)
ax.set_yticklabels(data_norm.columns)
plt.show()

# %%
import seaborn
df_seaborn_heatmap=data_norm[['observer_intensity', 'precipitation', 'temperature', 'municipality', 'roadlength', 'nature_reserves', 'built_up', 'dry_natural_terrain', 'coastal_water', 'agriculture', 'water']]
plt.figure(figsize=(18,18))
seaborn.heatmap(df_seaborn_heatmap.corr(), annot=True, cmap="coolwarm").set_title('Seaborn')
# Out:
# Text(0.5, 1.0, 'Seaborn')

# %%
corr
# Out:
#                             block       woy  observer_intensity  \
# block                    1.000000  0.016501           -0.092396
# woy                      0.016501  1.000000           -0.033108
# observer_intensity      -0.092396 -0.033108            1.000000
# precipitation            0.038055 -0.141347           -0.007263
# temperature              0.010632  0.921634           -0.036584
# pop001                  -0.130904 -0.009021           -0.022634
# pop009                  -0.178450 -0.010956           -0.007791
# pop025                  -0.213696 -0.011472            0.006073
# pop049                  -0.244556 -0.011657            0.017099
# pop081                  -0.272919 -0.011930            0.026406
# pop121                  -0.299044 -0.011991            0.033071
# pop169                  -0.323182 -0.011784            0.038735
# pop225                  -0.344271 -0.011418            0.044194
# municipality            -0.052662 -0.008933           -0.040901
# ...

# %% [markdown]
# ### Boxplots

# %%
fig, ax = plt.subplots(figsize=(24,10))
data_norm.boxplot(column=['precipitation', 'temperature', 'municipality', 'roadlength', 'nature_reserves', 'built_up', 'dry_natural_terrain', 'coastal_water', 'agriculture', 'water'])
# Out:
# <AxesSubplot:>

# %%
data_norm.columns

data_norm_new=data_norm[['observer_intensity','block', 'woy','precipitation', 'temperature',
       'pop001', 'pop009', 'pop025', 'pop049', 'pop081', 'pop121', 'pop169',
       'pop225', 'municipality', 'province', 'water_authority', 'rijk',
       'other_maintainers', 'roadlength', 'built_up', 'dry_natural_terrain',
       'greenhouse_horticulture', 'railway', 'nature_reserves', 'company_site',
       'wet_natural_terrain', 'airport', 'forest', 'coastal_water',
       'semi_built', 'agriculture', 'recreation', 'water', 'highway']]

# %%
df=data_norm_new.dropna()
pnr_value = pd.DataFrame (columns=['r','p'])

for col in data_norm_new:
    if pd.api.types.is_numeric_dtype(df[col]):
        r , p =stats.pearsonr (df.observer_intensity, df[col])
        pnr_value.loc[col]=[round(r,3), round(p,9)]
pnr_value
# Out:
#                              r         p
# observer_intensity       1.000  0.000000
# block                   -0.094  0.000000
# woy                     -0.034  0.000000
# precipitation           -0.007  0.000698
# temperature             -0.038  0.000000
# pop001                  -0.023  0.000000
# pop009                  -0.008  0.000021
# pop025                   0.006  0.002070
# pop049                   0.017  0.000000
# pop081                   0.026  0.000000
# pop121                   0.033  0.000000
# pop169                   0.038  0.000000
# pop225                   0.044  0.000000
# municipality            -0.041  0.000000
# province                -0.028  0.000000
# water_authority          0.018  0.000000
# rijk                     0.015  0.000000
# other_maintainers       -0.001  0.604986
# roadlength              -0.038  0.000000
# built_up                -0.039  0.000000
# dry_natural_terrain      0.077  0.000000
# greenhouse_horticulture -0.007  0.000715
# ...

# %%
df_seaborn_heatmap=pnr_value
plt.figure(figsize=(18,18))
seaborn.heatmap(df_seaborn_heatmap, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>
